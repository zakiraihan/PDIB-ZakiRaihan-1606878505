# %%
import pandas as pd
hmeq = pd.read_csv("hmeq.csv")
hmeq.head() #Look at the head of the data (just the first few rows)
# Out:
#    BAD  LOAN  MORTDUE     VALUE   REASON     JOB   YOJ  DEROG  DELINQ  \
# 0    1  1100  25860.0   39025.0  HomeImp   Other  10.5    0.0     0.0
# 1    1  1300  70053.0   68400.0  HomeImp   Other     7    0.0     2.0
# 2    1  1500  13500.0   16700.0  HomeImp   Other     4    0.0     0.0
# 3    1  1500      NaN       NaN      NaN     NaN   NaN    NaN     NaN
# 4    0  1700  97800.0  112000.0  HomeImp  Office     3    0.0     0.0
#
#         CLAGE  NINQ  CLNO  DEBTINC  Unnamed: 13  Unnamed: 14  Unnamed: 15  \
# 0   94.366667   1.0   9.0      NaN          NaN          NaN          NaN
# 1  121.833333   0.0  14.0      NaN          NaN          NaN          NaN
# 2  149.466667   1.0  10.0      NaN          NaN          NaN          NaN
# 3         NaN   NaN   NaN      NaN          NaN          NaN          NaN
# 4   93.333333   0.0  14.0      NaN          NaN          NaN          NaN
#
#    Unnamed: 16
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
hmeq_cleaned = hmeq.drop(columns=['Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16'])

# %%
hmeq_cleaned.describe()
# Out:
#                BAD          LOAN        MORTDUE         VALUE        DEROG  \
# count  5962.000000  5.962000e+03    5444.000000  5.850000e+03  5254.000000
# mean      0.201275  1.972605e+04   73756.449706  2.580738e+05     0.259136
# std       0.420589  8.597330e+04   44450.895907  1.176907e+07     0.890592
# min       0.000000  1.100000e+03    2063.000000 -2.500000e+04     0.000000
# 25%       0.000000  1.110000e+04   46292.000000  6.608575e+04     0.000000
# 50%       0.000000  1.640000e+04   65019.000000  8.924500e+04     0.000000
# 75%       0.000000  2.330000e+04   91482.000000  1.198388e+05     0.000000
# max      10.000000  6.600000e+06  399550.000000  9.001400e+08    20.000000
#
#             DELINQ        CLAGE         NINQ         CLNO      DEBTINC
# count  5382.000000  5654.000000  5452.000000  5740.000000  4695.000000
# mean      0.449275   179.738555     1.237366    21.287456    35.185829
# std       1.127090    85.853356     3.615545    10.141083    73.596762
# ...

# %%
hmeq_cleaned = hmeq_cleaned.fillna(hmeq.mean())

# %%
hmeq_cleaned.head()
# Out:
#    BAD  LOAN       MORTDUE         VALUE   REASON     JOB   YOJ     DEROG  \
# 0    1  1100  25860.000000   39025.00000  HomeImp   Other  10.5  0.000000
# 1    1  1300  70053.000000   68400.00000  HomeImp   Other     7  0.000000
# 2    1  1500  13500.000000   16700.00000  HomeImp   Other     4  0.000000
# 3    1  1500  73756.449706  258073.78599      NaN     NaN   NaN  0.259136
# 4    0  1700  97800.000000  112000.00000  HomeImp  Office     3  0.000000
#
#      DELINQ       CLAGE      NINQ       CLNO    DEBTINC
# 0  0.000000   94.366667  1.000000   9.000000  35.185829
# 1  2.000000  121.833333  0.000000  14.000000  35.185829
# 2  0.000000  149.466667  1.000000  10.000000  35.185829
# 3  0.449275  179.738555  1.237366  21.287456  35.185829
# 4  0.000000   93.333333  0.000000  14.000000  35.185829

# %%
hmeq_cleaned['JOB'].describe()
# Out:
# count      5683
# unique        7
# top       Other
# freq       2387
# Name: JOB, dtype: object
